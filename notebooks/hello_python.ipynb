# %% [markdown]
# # Hello Python
#
# Starter notebook for data science practice.

# %%
import sys
print(f"Python {sys.version}")
print("Ready to learn!")

# %%
# Optional: uncomment after installing pandas
# import pandas as pd
# pd.Series([1, 2, 3, 4, 5]).describe()
